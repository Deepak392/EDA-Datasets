# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading data
df = pd.read_csv(Amzon job reviews (USA  India) 2008-2020.csv\Amzon job reviews (USA  India) 2008-2020.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Deepa\AppData\Local\Temp\ipykernel_28396\3971721571.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("C:\\Users\Deepa\Downloads\Amzon job reviews (USA  India) 2008-2020.csv\Amzon job reviews (USA  India) 2008-2020.csv")

# %%
df.head()
# Out:
#    ID number         Date       Location                   Position  \
# 0          1  22 Apr 2008  Palo Alto, CA             Sales Director
# 1          2  23 Apr 2008  Lexington, KY      Systems Administrator
# 2          3   2 May 2008    Seattle, WA           Technical Writer
# 3          4  23 May 2008    Seattle, WA   Software Design Engineer
# 4          5  25 May 2008    Seattle, WA   Senior Marketing Manager
#
#                                 Comment for company   Overall ratting  \
# 0  Amazon isn't all it's cracked up to be, unless...              2.0
# 1                            Long hours and low pay.              2.0
# 2       A fair website, but sucks as a place to work              2.0
# 3  About what you'd expect when you sell your sou...              3.0
# 4      I can't believe I get paid to do what I love!              4.0
#
#    Work/Life Balance  Culture & Values  Diversity & Inclusion  \
# 0                1.5               NaN                    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29494 entries, 0 to 29493
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID number                  29494 non-null  int64
#  1   Date                       29494 non-null  object
#  2   Location                   29441 non-null  object
#  3   Position                   28986 non-null  object
#  4   Comment for company        29424 non-null  object
#  5   Overall ratting            29494 non-null  float64
#  6   Work/Life Balance          26691 non-null  float64
#  7   Culture & Values           25819 non-null  float64
#  8   Diversity & Inclusion      3821 non-null   float64
#  9   Career Opportunities       26717 non-null  float64
#  10  Compensation and Benefits  26706 non-null  float64
#  11  Senior Management          26366 non-null  float64
#  12  CEO Approval               22948 non-null  object
# ...

# %%
df.describe()
# Out:
#           ID number  Overall rating  Work/Life Balance  Career Opportunities  \
# count  29494.000000    29494.000000       26691.000000          29494.000000
# mean   14747.500000        3.712959           3.209940              3.346698
# std     8514.328756        1.245477           1.365527              1.647135
# min        1.000000        1.000000           1.000000              0.000000
# 25%     7374.250000        3.000000           2.000000              2.000000
# 50%    14747.500000        4.000000           3.000000              4.000000
# 75%    22120.750000        5.000000           4.000000              5.000000
# max    29494.000000        5.000000           5.000000              5.000000
#
#        Compensation and Benefits  Senior Management
# count               29494.000000       29494.000000
# mean                    3.457432           2.934648
# std                     1.550726           1.649749
# min                     0.000000           0.000000
# ...

# %%
df.isnull().sum()
# Out:
# ID number                        0
# Date                             0
# Location                        53
# Position                       508
# Comment for company             70
# Overall rating                   0
# Work/Life Balance             2803
# Culture & Values                 0
# Diversity & Inclusion            0
# Career Opportunities             0
# Compensation and Benefits        0
# Senior Management                0
# CEO Approval                     0
# Recommended                      0
# Business Outlook              5543
# Current employee                 0
# Former employee                  0
# Timeline                      5612
# cons                             0
# pros                             0
# advice to Management         14401
# review_url                       0
# dtype: int64

# %%
# Fill missing numeric columns with median
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].median())

# %%
df.isnull().sum()
# Out:
# ID number                        0
# Date                             0
# Location                        53
# Position                       508
# Comment for company             70
# Overall rating                   0
# Work/Life Balance                0
# Culture & Values                 0
# Diversity & Inclusion            0
# Career Opportunities             0
# Compensation and Benefits        0
# Senior Management                0
# CEO Approval                     0
# Recommended                      0
# Business Outlook              5543
# Current employee                 0
# Former employee                  0
# Timeline                      5612
# cons                             0
# pros                             0
# advice to Management         14401
# review_url                       0
# dtype: int64

# %%
df = df.rename({'Overall ratting':'Overall rating'}, axis = 1)

# %%
df['Culture & Values'] = df['Culture & Values'].fillna('NaN')
df['Diversity & Inclusion'] = df['Diversity & Inclusion'].fillna('NaN')
df['Career Opportunities'] = df['Career Opportunities'].fillna(0)
df['Compensation and Benefits'] = df['Compensation and Benefits'].fillna(0)
df['Senior Management'] = df['Senior Management'].fillna(0)
df['CEO Approval'] = df['CEO Approval'].fillna('NaN')
df['Recommended'] = df['Recommended'].fillna('NaN')


df.isnull().sum()
# Out:
# ID number                        0
# Date                             0
# Location                        53
# Position                       508
# Comment for company             70
# Overall rating                   0
# Work/Life Balance             2803
# Culture & Values                 0
# Diversity & Inclusion            0
# Career Opportunities             0
# Compensation and Benefits        0
# Senior Management                0
# CEO Approval                     0
# Recommended                      0
# Business Outlook              5543
# Current employee                 0
# Former employee                  0
# Timeline                      5612
# cons                             0
# pros                             0
# advice to Management         14401
# review_url                       0
# dtype: int64

# %% [markdown]
# **Performing EDA on Amazon Job Reviews**

# %%
df.head()
# Out:
#    ID number         Date       Location                   Position  \
# 0          1  22 Apr 2008  Palo Alto, CA             Sales Director
# 1          2  23 Apr 2008  Lexington, KY      Systems Administrator
# 2          3   2 May 2008    Seattle, WA           Technical Writer
# 3          4  23 May 2008    Seattle, WA   Software Design Engineer
# 4          5  25 May 2008    Seattle, WA   Senior Marketing Manager
#
#                                 Comment for company   Overall rating  \
# 0  Amazon isn't all it's cracked up to be, unless...             2.0
# 1                            Long hours and low pay.             2.0
# 2       A fair website, but sucks as a place to work             2.0
# 3  About what you'd expect when you sell your sou...             3.0
# 4      I can't believe I get paid to do what I love!             4.0
#
#    Work/Life Balance Culture & Values Diversity & Inclusion  \
# 0                1.5              NaN                   NaN
# ...

# %%
df['Position'].unique()
# Out:
# array([' Sales Director', ' Systems Administrator', ' Technical Writer',
#        ..., ' Territory Manager', ' Program Manager I, FinOps PMO',
#        ' Real Estate Manager'], dtype=object)
